# %% [markdown]
# # Nicotine Dependence
# ## Import dataframe which contains usernames and according phenotype

# %%
import pandas as pd

df = pd.read_csv('final_nicotine_dependence_df.csv')
raw_names = df["name"].tolist()
df

# %% [markdown]
# ## Change names in column "name"

# %%
temp_user = None

processed_names = []

sample_string = "836.23andme.413"

# delete ".23andme" and replace with "_file" and add "user" in front
def clean_name(filename: str):
    garbage = ".23andme."
    temp_string = filename.replace(garbage,"_file")
    return "user"+temp_string
new_names = []
for i in raw_names:
    new_names.append(clean_name(i))

df["name"] = new_names

df

# %% [markdown]
# ## Access files in directory
# ### all files

# %%
import os 

directory = "D:/Leah Data/patientFiles"
for filename in os.scandir(directory):
    if filename.is_file():
        print(filename.path)

# %% [markdown]
# ### files which end with 23andme.txt and 23andme-exome-vcf.txt

# %%
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    if filename.endswith("23andme.txt") or filename.endswith("23andme-exome-vcf.txt"):
        print(file)

# %% [markdown]
# ### 23andme.txt files from dataframe, patients nicotine dependence

# %%
# store names of 23andme.txt files in list
patient_files_nicotine = []

for file in os.listdir(directory):
    if file.startswith(tuple(new_names)):
        patient_files_nicotine.append(file)

print(len(patient_files_nicotine))

# %% [markdown]
# ## Iterating over files to clear and save as parquet

# %%
import os
import pandas as pd
from time import sleep

#check if lines include a Hash
def hasHash(line: str):
    if "#" in line:
        return True
    else:
        return False

#get RSID from textfile
def getRSID(line: str):
        return line[:line.index("\t")]

#get genotype from textfile
def getGenotype(line: str):
    if line[-3] == "\t":
        return line[-2:-1]
    else:
        return line[-3:-1]

#get position from textfile
def getPosition(line: str):
    counter = 0
    for i, char in enumerate(line):
        if char == "\t":
            counter = counter + 1

        if counter == 2:
            x = line[i+1:]
            return x[:x.index("\t")]


file_location = 'D:/Leah Data/patientFiles/'

successOpen = 0
failOpen = 0
failOpenArray = []

run = False

if run:

    # iterate through each filename in the list
    for i, fileName in enumerate(patient_files_nicotine):
        rsid = []
        position = []
        genotype = []

        #### Condition to check if we want to open the file
        print("Trying to open: ", fileName)
        
        # OPEN
        try:
            with open (file_location + fileName) as nicotinefile:
            #nicotinefile = open(file_location + fileName)
                fileContents = nicotinefile.readlines()
                
                # HERE GOES THE PROCESSING - FILE IS OPENED
                for line in fileContents:
                    if hasHash(line)==False:
                        rsid.append(getRSID(line))
                        genotype.append(getGenotype(line))
                        position.append(getPosition(line))
                        
                # SAVE FILE WITH THE ACC. DATA
                n = {"rsid":rsid, "position":position, "genotype":genotype}
                
                df_nicotine = pd.DataFrame(data = n)
                
                name="D:/nicotine_parquets/"+str(fileName)+".parquet"
                df_nicotine.to_parquet(name)
                
                successOpen = successOpen+1
                try:
                    del df_nicotine
                except:
                    print("Caught error for del df_: Continuining without problem")
        except:
            failOpen+=1
            failOpenArray.append(fileName)

        #if i == 3:
            #break

    print(f"Success opens: {successOpen}\nFailed opens: {failOpen}")

    print("File names of all failed files:")
    print(failOpenArray)

# %% [markdown]
# ## Data Cleaning

# %%
import pandas as pd

#Tracker to track RSIDs
RSID_Tracker = {}

#Condition if rsid starts with "r"
def rsidIsAllowed(rsid: str):
	if  rsid[0]=="r":
		return True
	else:
		return False

#Condition if genotype has an empty value or is smaller than 2 letters
def genotypeIsAllowed(genomeValue: str):
	if genomeValue == "--" or len(genomeValue)<2:
		return False
	else:
		return True

import os


read = False

clean_file_direction = "D:/nicotine_parquets/"


if read:
	common_rsid_counter = 0

	# Iterate through each parquet file and open
	for i, filename in enumerate(os.scandir("D:/nicotine_parquets")):		
		# if i == 5:
		# 	break

		# Read parquet file
		print(filename, "opened! Operating now...")
		patient = pd.read_parquet(filename)
		# Initiate new column fields for new "updated" df
		newRSID = []
		newGenotype=[]
		newPos = []

		# 1. get a list from genotype column (or make for loop)
		OG_genotype = patient["genotype"].tolist()
		
		# # 2 get a list from rsid column
		OG_RSID = patient["rsid"].tolist()

		# # 2.5 get list from positions
		OG_pos = patient["position"].tolist()

		print(f"found {len(OG_genotype)} genotypes")

		# 3. for each value in the list, check if genotype is allowed + for each value in the list, check if ID is allowed
		for j, genome in enumerate(OG_genotype):

			if genotypeIsAllowed(genome) and rsidIsAllowed(OG_RSID[j]):
				newGenotype.append(genome)
				newPos.append(OG_pos[j])
				newRSID.append(OG_RSID[j])
			
			# IN CASE OF ERROR TRACKING UNCOMMENT THE CODE BELOW
			
			# elif not rsidIsAllowed(OG_RSID[j]):
			# 	print("NOT ACCEPTING:", OG_RSID[j],". SKIPPING", OG_RSID[j])
			# elif not genotypeIsAllowed(genome):
			# 	print("NOT ACCEPTING:", genome,". SKIPPING",OG_RSID[j])

		# STORE THE RESULTS AS PARQUET FILES
		new_data = {"rsid":newRSID, "position": newPos, "genotype": newGenotype }
		df_new_patient = pd.DataFrame(data = new_data)

		df_new_patient.to_parquet(clean_file_direction + filename.name )
		print("Stored!")

# %% [markdown]
# ## Count all RSIDs and unique RSIDs

# %%
allRSIDS_nicotine = []
# allUniqueRSIDS = []

clean_file_direction = "D:/nicotine_parquets/"
read = False 

if read:

    # Iterate through parquet files
    for i, filename in enumerate(os.scandir(clean_file_direction)):
        print(filename , 'OPEN')
        file = pd.read_parquet(filename)

        # add every single rsid to list
        patientRSIDS = file["rsid"].tolist()
    
        for j, snp in enumerate(patientRSIDS):
            allRSIDS_nicotine.append(snp)
        
        # if snp not in allUniqueRSIDS:
        #     allUniqueRSIDS.append(snp)

        # allRSIDS_nicotine.append(patientRSIDS)
        print("Done. Next:")


    try:
        print(len(allRSIDS_nicotine))
    except:
        print("Couldn't print LEN for some reason")

# %%
# Create .csv file with all listed RSIDS 
import pandas as pd 
#r = pd.DataFrame({"all_rsids":allRSIDS_nicotine})
#r

#r.to_csv("ALL_RSIDS_nicotine.csv", index=False)

# %% [markdown]
# ## List rsids in patients and count them

# %%
RSID_Tracker = {}

frame = pd.read_csv("ALL_RSIDS_nicotine.csv")

print("Opening done.")
print("Counting now.")

read = False
if read:

    # Iterate through each RSID in list and count how often they occure
    for i, rsid in enumerate(frame["all_rsids"].tolist()):
    
    
        if rsid in RSID_Tracker:
            RSID_Tracker[rsid]+=1
        else:
            RSID_Tracker[rsid] = 1

    import json

    # Save results as jason file
    print("Done. Attempting to save as JSON...")
    with open('counted_RSIDS_nicotine.json', 'w') as fp:
        json.dump(RSID_Tracker, fp)

    print("Done!")

# %% [markdown]
# ## rsids which occure at least in 97% of patients

# %%
import json
import pandas as pd

# Calculation of in how many patients a rsid needs to occure to show a minimun occurence og 97%
n_minimum_occurence = int((418/100)* 97)+1
print(n_minimum_occurence)

# Open file
print("Opening JSON FILE")

f = open("counted_RSIDS_nicotine.json")
data = json.load(f)

print(len(data))

# Create list with common rsids
most_common_rsids_nicotine_patients = []

for i, key in enumerate(data):
    # print(i)
    if data[key] >= n_minimum_occurence:

        if key not in most_common_rsids_nicotine_patients:
            most_common_rsids_nicotine_patients.append(key)

f.close()
print(len(most_common_rsids_nicotine_patients))

store = False

# Create .csv file to store thr most common rsids
if store:
    print("Done. Attempting to store....")
    common_rsids = pd.DataFrame({"common_rsids":most_common_rsids_nicotine_patients})
    common_rsids.to_csv("common_rsids_nicotine.csv", index=False)
    print("Done storing.")

# %% [markdown]
# ## Get username of patients with most common rsids

# %%
c = pd.read_csv("common_rsids_nicotine.csv")

# Create a list of common rsids and look at the lenght of the list
commons = c["common_rsids"].tolist()
len(commons)

user_with_common_rsids = []

user_names = []

run = True

if run:

# # If 100% of rsid are in file
    def isFit(patient_rsid_list: list, necessary: list):
        
        is_included = 0
        
        for k, value in enumerate(necessary):
            if value in patient_rsid_list:
                is_included+=1
        
        if is_included/len(necessary)>=1:
            return True
        else:
            return False

    clean_file_direction = "D:/nicotine_parquets/"

    for j, filename in enumerate(os.scandir(clean_file_direction)):
        
        # Open file and read
        print(j, filename, 'OPEN')
        
        file = pd.read_parquet(filename)

        if isFit(file["rsid"].tolist(),commons):
            print(filename,"is fit")
            user_names.append(filename.name)
        else:
            print(filename," NOT FIT !!!!!!")

    print(user_names)

    users = pd.DataFrame({"userID":user_names})

    users.to_csv("5k_Nicotine_Users_Cleaned.csv", index=False)
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Get username, rsid and genotype and store it in a dataframe

# %%
import pandas as pd
import numpy as np
import warnings
import time

warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)

def get_genotype_values(patientID: str, target_snps: list):    
    Userfile = pd.read_parquet(clean_file_direction + patientID)
    print(f"Opened {user.index(patientID)}/{len(user)}: {patientID}.")

    start_timestamp=time.time()

    patient_rsids = Userfile["rsid"].tolist()
    patient_genotype_list = Userfile["genotype"].tolist()
    new_row_vals = []

    for s, gene in enumerate(target_snps):
        try:
            new_row_vals.append(patient_genotype_list[patient_rsids.index(gene)])
        except:
            print(f"ERROR: {gene} couldn't identify val for {patientID}")
            new_row_vals.append(np.nan)
        #if s == 3:
            #break
    end = time.time()

    
    process_time = str(end-start_timestamp)[:5]
    print(f"This file took {process_time} seconds.\n")

    return new_row_vals
   


users = pd.read_csv('5k_Nicotine_Users_Cleaned.csv')
c = pd.read_csv("common_rsids_nicotine.csv")
user = users["userID"].tolist()
GenoTypes = pd.DataFrame({"userID": user})

clean_file_direction = "D:/nicotine_parquets/"
print("Constructing empty dataframe structure...")
col_vals = c["common_rsids"].tolist()



# Update all rows using labda function
gen_vals = GenoTypes.apply(lambda row: get_genotype_values(row["userID"],col_vals), axis = 1)
print(gen_vals)

for i in col_vals:
    GenoTypes[i] = gen_vals
print("Finished construction.")


for i, u in enumerate(user):
    new_row = gen_vals[i]
    for j, col in enumerate(GenoTypes.columns):
        if col == "userID":
            pass
        else:
            GenoTypes.at[i, col] = new_row[j-1]

GenoTypes.to_csv("Nicotine_Dependence_DF.csv", index=False)
print("Storing done.")
#print(GenoTypes)
# Out:
# Constructing empty dataframe structure...
# Opened 0/404: user10020_file8283_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 16.36 seconds.
#
# Opened 1/404: user1020_file507_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 28.44 seconds.
#
# Opened 2/404: user1024_file510_yearofbirth_1971_sex_XX.23andme.txt.parquet.
# This file took 28.02 seconds.
#
# Opened 3/404: user1028_file514_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 28.68 seconds.
#
# Opened 4/404: user1029_file515_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 28.51 seconds.
#
# Opened 5/404: user10300_file8552_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 17.56 seconds.
#
# Opened 6/404: user10374_file8624_yearofbirth_1973_sex_XX.23andme.txt.parquet.
# This file took 28.79 seconds.
#
# Opened 7/404: user1038_file520_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 28.46 seconds.
#
# Opened 8/404: user1039_file521_yearofbirth_1958_sex_XY.23andme.txt.parquet.
# This file took 28.71 seconds.
#
# Opened 9/404: user10408_file8659_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 17.19 seconds.
#
# Opened 10/404: user1040_file522_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 28.82 seconds.
#
# Opened 11/404: user10431_file8696_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 17.84 seconds.
#
# Opened 12/404: user10431_file8698_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 17.84 seconds.
#
# Opened 13/404: user10431_file8699_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 17.94 seconds.
#
# Opened 14/404: user10431_file9261_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 17.94 seconds.
#
# Opened 15/404: user10469_file8739_yearofbirth_1999_sex_XX.23andme.txt.parquet.
# This file took 17.83 seconds.
#
# Opened 16/404: user10507_file8778_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 18.53 seconds.
#
# Opened 17/404: user1051_file530_yearofbirth_1949_sex_unknown.23andme.txt.parquet.
# This file took 28.08 seconds.
#
# Opened 18/404: user1059_file535_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 22.78 seconds.
#
# Opened 19/404: user1060_file536_yearofbirth_1971_sex_unknown.23andme.txt.parquet.
# This file took 30.05 seconds.
#
# Opened 20/404: user1075_file550_yearofbirth_1963_sex_XX.23andme.txt.parquet.
# This file took 30.23 seconds.
#
# Opened 21/404: user1089_file559_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 30.23 seconds.
#
# Opened 22/404: user10919_file9022_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 18.39 seconds.
#
# Opened 23/404: user10_file3_yearofbirth_1982_sex_XY.23andme.txt.parquet.
# This file took 30.99 seconds.
#
# Opened 24/404: user10_file903_yearofbirth_1982_sex_XY.23andme.txt.parquet.
# This file took 30.85 seconds.
#
# Opened 25/404: user11008_file9131_yearofbirth_1998_sex_unknown.23andme.txt.parquet.
# This file took 18.83 seconds.
#
# Opened 26/404: user1104_file2221_yearofbirth_1972_sex_XX.23andme.txt.parquet.
# This file took 30.07 seconds.
#
# Opened 27/404: user1104_file2222_yearofbirth_1972_sex_XX.23andme.txt.parquet.
# This file took 30.30 seconds.
#
# Opened 28/404: user1104_file8688_yearofbirth_1972_sex_XX.23andme.txt.parquet.
# This file took 30.22 seconds.
#
# Opened 29/404: user11056_file9168_yearofbirth_1991_sex_XY.23andme.txt.parquet.
# This file took 18.08 seconds.
#
# Opened 30/404: user1114_file574_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 30.30 seconds.
#
# Opened 31/404: user11173_file9325_yearofbirth_unknown_sex_XX.23andme.txt.parquet.
# This file took 19.03 seconds.
#
# Opened 32/404: user1125_file582_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 30.42 seconds.
#
# Opened 33/404: user1147_file598_yearofbirth_1948_sex_XY.23andme.txt.parquet.
# This file took 30.12 seconds.
#
# Opened 34/404: user1163_file603_yearofbirth_1987_sex_unknown.23andme.txt.parquet.
# This file took 30.41 seconds.
#
# Opened 35/404: user1190_file626_yearofbirth_unknown_sex_XX.23andme.txt.parquet.
# This file took 30.75 seconds.
#
# Opened 36/404: user1193_file628_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 30.40 seconds.
#
# Opened 37/404: user1196_file631_yearofbirth_unknown_sex_XY.23andme.txt.parquet.
# This file took 30.97 seconds.
#
# Opened 38/404: user11_file176_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 31.48 seconds.
#
# Opened 39/404: user1221_file648_yearofbirth_1965_sex_XY.23andme.txt.parquet.
# This file took 30.95 seconds.
#
# Opened 40/404: user124_file55_yearofbirth_1947_sex_XX.23andme.txt.parquet.
# This file took 31.24 seconds.
#
# Opened 41/404: user1258_file664_yearofbirth_1980_sex_XY.23andme.txt.parquet.
# This file took 30.94 seconds.
#
# Opened 42/404: user1269_file673_yearofbirth_1967_sex_XX.23andme.txt.parquet.
# This file took 31.03 seconds.
#
# Opened 43/404: user1281_file682_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 28.13 seconds.
#
# Opened 44/404: user1325_file706_yearofbirth_1977_sex_XX.23andme.txt.parquet.
# This file took 31.68 seconds.
#
# Opened 45/404: user1364_file718_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 31.78 seconds.
#
# Opened 46/404: user1366_file721_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 32.17 seconds.
#
# Opened 47/404: user1375_file726_yearofbirth_1976_sex_XX.23andme.txt.parquet.
# This file took 32.35 seconds.
#
# Opened 48/404: user1430_file772_yearofbirth_1981_sex_XY.23andme.txt.parquet.
# This file took 31.73 seconds.
#
# Opened 49/404: user1446_file788_yearofbirth_1974_sex_XY.23andme.txt.parquet.
# This file took 31.93 seconds.
#
# Opened 50/404: user1457_file795_yearofbirth_1961_sex_XY.23andme.txt.parquet.
# This file took 31.91 seconds.
#
# Opened 51/404: user1465_file803_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 31.92 seconds.
#
# Opened 52/404: user146_file62_yearofbirth_1971_sex_XY.23andme.txt.parquet.
# This file took 32.41 seconds.
#
# Opened 53/404: user1499_file818_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 31.98 seconds.
#
# Opened 54/404: user14_file6_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 19.88 seconds.
#
# Opened 55/404: user1532_file844_yearofbirth_1970_sex_XY.23andme.txt.parquet.
# This file took 24.10 seconds.
#
# Opened 56/404: user1537_file846_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 19.11 seconds.
#
# Opened 57/404: user154_file65_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 33.31 seconds.
#
# Opened 58/404: user1568_file878_yearofbirth_1971_sex_XX.23andme.txt.parquet.
# This file took 19.28 seconds.
#
# Opened 59/404: user159_file67_yearofbirth_1984_sex_XX.23andme.txt.parquet.
# This file took 33.28 seconds.
#
# Opened 60/404: user160_file153_yearofbirth_1954_sex_unknown.23andme.txt.parquet.
# This file took 33.19 seconds.
#
# Opened 61/404: user161_file5355_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 34.37 seconds.
#
# Opened 62/404: user161_file68_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 20.13 seconds.
#
# Opened 63/404: user1675_file960_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 19.38 seconds.
#
# Opened 64/404: user16_file3446_yearofbirth_1966_sex_XY.23andme.txt.parquet.
# This file took 19.44 seconds.
#
# Opened 65/404: user1706_file986_yearofbirth_1978_sex_XX.23andme.txt.parquet.
# This file took 19.48 seconds.
#
# Opened 66/404: user1712_file988_yearofbirth_1953_sex_unknown.23andme.txt.parquet.
# This file took 33.25 seconds.
#
# Opened 67/404: user1742_file1010_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 33.19 seconds.
#
# Opened 68/404: user1764_file1025_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 33.23 seconds.
#
# Opened 69/404: user1778_file1034_yearofbirth_1966_sex_XY.23andme.txt.parquet.
# This file took 32.71 seconds.
#
# Opened 70/404: user177_file78_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 35.54 seconds.
#
# Opened 71/404: user17_file143_yearofbirth_unknown_sex_XX.23andme.txt.parquet.
# This file took 20.99 seconds.
#
# Opened 72/404: user187_file267_yearofbirth_1951_sex_XY.23andme.txt.parquet.
# This file took 21.37 seconds.
#
# Opened 73/404: user189_file174_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 35.44 seconds.
#
# Opened 74/404: user1952_file1206_yearofbirth_1981_sex_XY.23andme.txt.parquet.
# This file took 20.41 seconds.
#
# Opened 75/404: user1952_file3713_yearofbirth_1981_sex_XY.23andme.txt.parquet.
# This file took 20.42 seconds.
#
# Opened 76/404: user1963_file1153_yearofbirth_1980_sex_XY.23andme.txt.parquet.
# This file took 35.19 seconds.
#
# Opened 77/404: user1964_file1683_yearofbirth_1990_sex_XY.23andme.txt.parquet.
# This file took 25.88 seconds.
#
# Opened 78/404: user1964_file4905_yearofbirth_1990_sex_XY.23andme.txt.parquet.
# This file took 20.24 seconds.
#
# Opened 79/404: user1975_file1162_yearofbirth_1992_sex_XY.23andme.txt.parquet.
# This file took 20.60 seconds.
#
# Opened 80/404: user1980_file1166_yearofbirth_1975_sex_unknown.23andme.txt.parquet.
# This file took 35.08 seconds.
#
# Opened 81/404: user1987_file1174_yearofbirth_unknown_sex_XY.23andme.txt.parquet.
# This file took 35.09 seconds.
#
# Opened 82/404: user2004_file1189_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 20.60 seconds.
#
# Opened 83/404: user2008_file1193_yearofbirth_1963_sex_XX.23andme.txt.parquet.
# This file took 20.61 seconds.
#
# Opened 84/404: user2013_file1197_yearofbirth_1969_sex_other.23andme.txt.parquet.
# This file took 20.54 seconds.
#
# Opened 85/404: user2013_file7912_yearofbirth_1969_sex_other.23andme.txt.parquet.
# This file took 20.37 seconds.
#
# Opened 86/404: user202_file85_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 36.03 seconds.
#
# Opened 87/404: user2034_file1216_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 20.64 seconds.
#
# Opened 88/404: user2075_file1250_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 20.79 seconds.
#
# Opened 89/404: user2076_file1251_yearofbirth_unknown_sex_XY.23andme.txt.parquet.
# This file took 20.90 seconds.
#
# Opened 90/404: user2116_file1284_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 20.76 seconds.
#
# Opened 91/404: user2159_file1311_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 20.81 seconds.
#
# Opened 92/404: user216_file109_yearofbirth_1984_sex_XY.23andme.txt.parquet.
# This file took 36.35 seconds.
#
# Opened 93/404: user2288_file1401_yearofbirth_1942_sex_XX.23andme.txt.parquet.
# This file took 35.85 seconds.
#
# Opened 94/404: user2288_file1431_yearofbirth_1942_sex_XX.23andme.txt.parquet.
# This file took 35.51 seconds.
#
# Opened 95/404: user2288_file1439_yearofbirth_1942_sex_XX.23andme.txt.parquet.
# This file took 35.33 seconds.
#
# Opened 96/404: user2297_file1408_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 20.71 seconds.
#
# Opened 97/404: user2302_file1413_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 20.85 seconds.
#
# Opened 98/404: user2307_file1417_yearofbirth_1979_sex_XX.23andme.txt.parquet.
# This file took 35.56 seconds.
#
# Opened 99/404: user2339_file1448_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 35.72 seconds.
#
# Opened 100/404: user2371_file1469_yearofbirth_1968_sex_XY.23andme.txt.parquet.
# This file took 35.96 seconds.
#
# Opened 101/404: user2385_file1478_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 35.68 seconds.
#
# Opened 102/404: user2406_file1498_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 20.94 seconds.
#
# Opened 103/404: user2411_file1502_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 20.94 seconds.
#
# Opened 104/404: user2412_file1503_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 36.28 seconds.
#
# Opened 105/404: user2412_file5273_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 36.37 seconds.
#
# Opened 106/404: user2455_file1519_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 21.06 seconds.
#
# Opened 107/404: user2456_file1553_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 36.26 seconds.
#
# Opened 108/404: user2457_file1521_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 21.23 seconds.
#
# Opened 109/404: user2516_file1545_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 36.53 seconds.
#
# Opened 110/404: user2533_file1566_yearofbirth_1969_sex_XX.23andme.txt.parquet.
# This file took 38.40 seconds.
#
# Opened 111/404: user2533_file4133_yearofbirth_1969_sex_XX.23andme.txt.parquet.
# This file took 38.42 seconds.
#
# Opened 112/404: user2533_file5275_yearofbirth_1969_sex_XX.23andme.txt.parquet.
# This file took 38.26 seconds.
#
# Opened 113/404: user2557_file1575_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 21.96 seconds.
#
# Opened 114/404: user2558_file1576_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 39.29 seconds.
#
# Opened 115/404: user2570_file1590_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 22.45 seconds.
#
# Opened 116/404: user2660_file1675_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 23.72 seconds.
#
# Opened 117/404: user26_file10_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 39.60 seconds.
#
# Opened 118/404: user2724_file1731_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 38.84 seconds.
#
# Opened 119/404: user2743_file1747_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 22.55 seconds.
#
# Opened 120/404: user2755_file1758_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 22.61 seconds.
#
# Opened 121/404: user2758_file1761_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 22.56 seconds.
#
# Opened 122/404: user276_file110_yearofbirth_1972_sex_XY.23andme.txt.parquet.
# This file took 39.45 seconds.
#
# Opened 123/404: user2797_file1771_yearofbirth_1990_sex_XY.23andme.txt.parquet.
# This file took 22.62 seconds.
#
# Opened 124/404: user2811_file1778_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 22.12 seconds.
#
# Opened 125/404: user2826_file1787_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 22.70 seconds.
#
# Opened 126/404: user2849_file1808_yearofbirth_1976_sex_XY.23andme.txt.parquet.
# This file took 41.05 seconds.
#
# Opened 127/404: user285_file118_yearofbirth_1976_sex_XY.23andme.txt.parquet.
# This file took 39.32 seconds.
#
# Opened 128/404: user294_file125_yearofbirth_1963_sex_XY.23andme.txt.parquet.
# This file took 38.23 seconds.
#
# Opened 129/404: user2964_file1892_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 22.85 seconds.
#
# Opened 130/404: user2969_file4132_yearofbirth_1990_sex_XX.23andme.txt.parquet.
# This file took 40.44 seconds.
#
# Opened 131/404: user296_file127_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 40.57 seconds.
#
# Opened 132/404: user2996_file1916_yearofbirth_1973_sex_XX.23andme.txt.parquet.
# This file took 23.33 seconds.
#
# Opened 133/404: user3004_file1925_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 40.21 seconds.
#
# Opened 134/404: user3046_file1955_yearofbirth_1979_sex_unknown.23andme.txt.parquet.
# This file took 23.22 seconds.
#
# Opened 135/404: user3078_file1981_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 23.03 seconds.
#
# Opened 136/404: user3196_file2078_yearofbirth_1989_sex_XX.23andme.txt.parquet.
# This file took 23.24 seconds.
#
# Opened 137/404: user319_file504_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 40.75 seconds.
#
# Opened 138/404: user3257_file2282_yearofbirth_1966_sex_XY.23andme.txt.parquet.
# This file took 23.19 seconds.
#
# Opened 139/404: user3257_file5298_yearofbirth_1966_sex_XY.23andme.txt.parquet.
# This file took 23.58 seconds.
#
# Opened 140/404: user3265_file2123_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 24.46 seconds.
#
# Opened 141/404: user3280_file2134_yearofbirth_1991_sex_unknown.23andme.txt.parquet.
# This file took 41.61 seconds.
#
# Opened 142/404: user3289_file2139_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 24.81 seconds.
#
# Opened 143/404: user328_file316_yearofbirth_1992_sex_XY.23andme.txt.parquet.
# This file took 42.14 seconds.
#
# Opened 144/404: user330_file146_yearofbirth_unknown_sex_XY.23andme.txt.parquet.
# This file took 42.39 seconds.
#
# Opened 145/404: user3321_file2162_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 24.32 seconds.
#
# Opened 146/404: user3321_file2163_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 24.40 seconds.
#
# Opened 147/404: user337_file152_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 42.10 seconds.
#
# Opened 148/404: user3397_file7911_yearofbirth_1977_sex_XY.23andme.txt.parquet.
# This file took 25.73 seconds.
#
# Opened 149/404: user341_file155_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 42.44 seconds.
#
# Opened 150/404: user345_file192_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 42.02 seconds.
#
# Opened 151/404: user3478_file2262_yearofbirth_1978_sex_XX.23andme.txt.parquet.
# This file took 24.45 seconds.
#
# Opened 152/404: user347_file157_yearofbirth_1952_sex_XX.23andme.txt.parquet.
# This file took 43.67 seconds.
#
# Opened 153/404: user3486_file2266_yearofbirth_1983_sex_XX.23andme.txt.parquet.
# This file took 24.24 seconds.
#
# Opened 154/404: user3494_file2270_yearofbirth_unknown_sex_XY.23andme.txt.parquet.
# This file took 24.71 seconds.
#
# Opened 155/404: user3494_file4394_yearofbirth_unknown_sex_XY.23andme.txt.parquet.
# This file took 24.50 seconds.
#
# Opened 156/404: user3532_file2305_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 23.98 seconds.
#
# Opened 157/404: user35_file5822_yearofbirth_unknown_sex_XY.23andme.txt.parquet.
# This file took 25.72 seconds.
#
# Opened 158/404: user3611_file2372_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 24.56 seconds.
#
# Opened 159/404: user3639_file2392_yearofbirth_unknown_sex_XX.23andme.txt.parquet.
# This file took 24.35 seconds.
#
# Opened 160/404: user363_file165_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 42.31 seconds.
#
# Opened 161/404: user3642_file2394_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 24.45 seconds.
#
# Opened 162/404: user366_file167_yearofbirth_1950_sex_XY.23andme.txt.parquet.
# This file took 42.91 seconds.
#
# Opened 163/404: user368_file168_yearofbirth_1958_sex_XX.23andme.txt.parquet.
# This file took 42.80 seconds.
#
# Opened 164/404: user36_file14_yearofbirth_1986_sex_XY.23andme.txt.parquet.
# This file took 44.14 seconds.
#
# Opened 165/404: user3766_file2493_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 24.77 seconds.
#
# Opened 166/404: user3795_file2558_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 24.71 seconds.
#
# Opened 167/404: user380_file172_yearofbirth_unknown_sex_XY.23andme.txt.parquet.
# This file took 43.03 seconds.
#
# Opened 168/404: user3821_file2539_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 24.71 seconds.
#
# Opened 169/404: user3853_file2654_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 24.71 seconds.
#
# Opened 170/404: user3865_file2575_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 24.71 seconds.
#
# Opened 171/404: user3866_file2576_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 24.24 seconds.
#
# Opened 172/404: user3867_file2577_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 24.76 seconds.
#
# Opened 173/404: user3867_file3643_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 24.62 seconds.
#
# Opened 174/404: user3881_file2588_yearofbirth_1960_sex_XX.23andme.txt.parquet.
# This file took 24.70 seconds.
#
# Opened 175/404: user3913_file2617_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 24.70 seconds.
#
# Opened 176/404: user3934_file2634_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 24.74 seconds.
#
# Opened 177/404: user3942_file2642_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 25.88 seconds.
#
# Opened 178/404: user3967_file2663_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 24.52 seconds.
#
# Opened 179/404: user3992_file2686_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 24.76 seconds.
#
# Opened 180/404: user4009_file2701_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 24.75 seconds.
#
# Opened 181/404: user4029_file2821_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 24.84 seconds.
#
# Opened 182/404: user4032_file7141_yearofbirth_1986_sex_XY.23andme.txt.parquet.
# This file took 26.21 seconds.
#
# Opened 183/404: user4034_file2725_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 25.81 seconds.
#
# Opened 184/404: user4048_file2734_yearofbirth_1954_sex_XX.23andme.txt.parquet.
# This file took 44.85 seconds.
#
# Opened 185/404: user4055_file2740_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 25.87 seconds.
#
# Opened 186/404: user4066_file5667_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 25.70 seconds.
#
# Opened 187/404: user4095_file2771_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 25.04 seconds.
#
# Opened 188/404: user4130_file2797_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 25.78 seconds.
#
# Opened 189/404: user4143_file2809_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 25.70 seconds.
#
# Opened 190/404: user4181_file2839_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 25.61 seconds.
#
# Opened 191/404: user4191_file2844_yearofbirth_unknown_sex_XY.23andme.txt.parquet.
# This file took 25.73 seconds.
#
# Opened 192/404: user429_file187_yearofbirth_1950_sex_XY.23andme.txt.parquet.
# This file took 44.84 seconds.
#
# Opened 193/404: user42_file18_yearofbirth_1985_sex_XY.23andme.txt.parquet.
# This file took 45.27 seconds.
#
# Opened 194/404: user4342_file3029_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 44.38 seconds.
#
# Opened 195/404: user4356_file2928_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 25.62 seconds.
#
# Opened 196/404: user437_file190_yearofbirth_1973_sex_XY.23andme.txt.parquet.
# This file took 46.15 seconds.
#
# Opened 197/404: user441_file199_yearofbirth_1989_sex_XY.23andme.txt.parquet.
# This file took 44.94 seconds.
#
# Opened 198/404: user4428_file3034_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 25.64 seconds.
#
# Opened 199/404: user4438_file3042_yearofbirth_1944_sex_XX.23andme.txt.parquet.
# This file took 43.83 seconds.
#
# Opened 200/404: user4482_file3079_yearofbirth_1949_sex_XY.23andme.txt.parquet.
# This file took 25.50 seconds.
#
# Opened 201/404: user4509_file3106_yearofbirth_unknown_sex_XY.23andme.txt.parquet.
# This file took 25.27 seconds.
#
# Opened 202/404: user4532_file3128_yearofbirth_1993_sex_XX.23andme.txt.parquet.
# This file took 25.77 seconds.
#
# Opened 203/404: user4539_file3133_yearofbirth_1982_sex_XY.23andme.txt.parquet.
# This file took 25.62 seconds.
#
# Opened 204/404: user4558_file3150_yearofbirth_unknown_sex_XY.23andme.txt.parquet.
# This file took 44.92 seconds.
#
# Opened 205/404: user4558_file4545_yearofbirth_unknown_sex_XY.23andme.txt.parquet.
# This file took 44.93 seconds.
#
# Opened 206/404: user4577_file3161_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 25.66 seconds.
#
# Opened 207/404: user4577_file7906_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 27.27 seconds.
#
# Opened 208/404: user4577_file8223_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 67.92 seconds.
#
# Opened 209/404: user4580_file3227_yearofbirth_1952_sex_XX.23andme.txt.parquet.
# This file took 25.47 seconds.
#
# Opened 210/404: user4601_file3203_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 44.44 seconds.
#
# Opened 211/404: user4605_file3207_yearofbirth_1973_sex_XY.23andme.txt.parquet.
# This file took 25.61 seconds.
#
# Opened 212/404: user4605_file8278_yearofbirth_1973_sex_XY.23andme.txt.parquet.
# This file took 25.36 seconds.
#
# Opened 213/404: user466_file447_yearofbirth_1983_sex_unknown.23andme.txt.parquet.
# This file took 46.03 seconds.
#
# Opened 214/404: user468_file200_yearofbirth_1978_sex_XX.23andme.txt.parquet.
# This file took 45.38 seconds.
#
# Opened 215/404: user4712_file3311_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 25.89 seconds.
#
# Opened 216/404: user4756_file3345_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 25.95 seconds.
#
# Opened 217/404: user4784_file3373_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 44.46 seconds.
#
# Opened 218/404: user4825_file3403_yearofbirth_1979_sex_XY.23andme.txt.parquet.
# This file took 25.88 seconds.
#
# Opened 219/404: user4831_file3406_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 25.80 seconds.
#
# Opened 220/404: user4845_file3416_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 26.02 seconds.
#
# Opened 221/404: user4879_file3436_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 26.03 seconds.
#
# Opened 222/404: user4935_file3479_yearofbirth_1979_sex_XY.23andme.txt.parquet.
# This file took 26.18 seconds.
#
# Opened 223/404: user4941_file4573_yearofbirth_1997_sex_XY.23andme.txt.parquet.
# This file took 44.88 seconds.
#
# Opened 224/404: user4943_file3490_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 26.13 seconds.
#
# Opened 225/404: user495_file223_yearofbirth_1965_sex_XX.23andme.txt.parquet.
# This file took 45.82 seconds.
#
# Opened 226/404: user4981_file3519_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 26.15 seconds.
#
# Opened 227/404: user4985_file3522_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 26.30 seconds.
#
# Opened 228/404: user4990_file5511_yearofbirth_1961_sex_XX.23andme.txt.parquet.
# This file took 26.28 seconds.
#
# Opened 229/404: user4998_file3538_yearofbirth_1952_sex_unknown.23andme.txt.parquet.
# This file took 45.01 seconds.
#
# Opened 230/404: user5007_file3546_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 45.19 seconds.
#
# Opened 231/404: user500_file2637_yearofbirth_1956_sex_XY.23andme.txt.parquet.
# This file took 46.19 seconds.
#
# Opened 232/404: user5017_file3551_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 26.41 seconds.
#
# Opened 233/404: user502_file226_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 45.98 seconds.
#
# Opened 234/404: user503_file274_yearofbirth_1962_sex_XX.23andme.txt.parquet.
# This file took 46.34 seconds.
#
# Opened 235/404: user5044_file3573_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 45.46 seconds.
#
# Opened 236/404: user5048_file3577_yearofbirth_1968_sex_unknown.23andme.txt.parquet.
# This file took 26.24 seconds.
#
# Opened 237/404: user5098_file3615_yearofbirth_1951_sex_XX.23andme.txt.parquet.
# This file took 46.50 seconds.
#
# Opened 238/404: user5136_file3648_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 26.69 seconds.
#
# Opened 239/404: user5164_file3672_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 26.62 seconds.
#
# Opened 240/404: user5168_file3676_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 26.01 seconds.
#
# Opened 241/404: user5180_file3689_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 26.49 seconds.
#
# Opened 242/404: user5211_file3722_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 25.99 seconds.
#
# Opened 243/404: user5235_file3749_yearofbirth_1978_sex_XY.23andme.txt.parquet.
# This file took 46.04 seconds.
#
# Opened 244/404: user5246_file3758_yearofbirth_1997_sex_XY.23andme.txt.parquet.
# This file took 26.84 seconds.
#
# Opened 245/404: user5249_file5451_yearofbirth_1977_sex_XX.23andme.txt.parquet.
# This file took 28.55 seconds.
#
# Opened 246/404: user5274_file3783_yearofbirth_1958_sex_XY.23andme.txt.parquet.
# This file took 26.97 seconds.
#
# Opened 247/404: user5274_file6322_yearofbirth_1958_sex_XY.23andme.txt.parquet.
# This file took 26.98 seconds.
#
# Opened 248/404: user528_file240_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 46.13 seconds.
#
# Opened 249/404: user5319_file3825_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 26.99 seconds.
#
# Opened 250/404: user539_file246_yearofbirth_1983_sex_XX.23andme.txt.parquet.
# This file took 46.74 seconds.
#
# Opened 251/404: user5443_file3943_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 28.14 seconds.
#
# Opened 252/404: user5471_file3967_yearofbirth_unknown_sex_XX.23andme.txt.parquet.
# This file took 27.01 seconds.
#
# Opened 253/404: user5475_file3971_yearofbirth_1967_sex_XY.23andme.txt.parquet.
# This file took 26.74 seconds.
#
# Opened 254/404: user5478_file3973_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 26.93 seconds.
#
# Opened 255/404: user5487_file3981_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 27.34 seconds.
#
# Opened 256/404: user5499_file3994_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 27.47 seconds.
#
# Opened 257/404: user549_file252_yearofbirth_1948_sex_XY.23andme.txt.parquet.
# This file took 48.04 seconds.
#
# Opened 258/404: user5515_file4007_yearofbirth_1986_sex_XY.23andme.txt.parquet.
# This file took 27.46 seconds.
#
# Opened 259/404: user5602_file4096_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 27.20 seconds.
#
# Opened 260/404: user561_file257_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 47.46 seconds.
#
# Opened 261/404: user5675_file4159_yearofbirth_1981_sex_XY.23andme.txt.parquet.
# This file took 27.51 seconds.
#
# Opened 262/404: user5719_file4214_yearofbirth_1959_sex_XX.23andme.txt.parquet.
# This file took 27.97 seconds.
#
# Opened 263/404: user574_file262_yearofbirth_1959_sex_XY.23andme.txt.parquet.
# This file took 48.39 seconds.
#
# Opened 264/404: user5800_file4277_yearofbirth_1966_sex_XX.23andme.txt.parquet.
# This file took 27.76 seconds.
#
# Opened 265/404: user583_file268_yearofbirth_1983_sex_XY.23andme.txt.parquet.
# This file took 48.71 seconds.
#
# Opened 266/404: user5878_file4352_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 27.67 seconds.
#
# Opened 267/404: user5902_file4372_yearofbirth_1983_sex_XX.23andme.txt.parquet.
# This file took 28.12 seconds.
#
# Opened 268/404: user5902_file4842_yearofbirth_1983_sex_XX.23andme.txt.parquet.
# This file took 28.20 seconds.
#
# Opened 269/404: user5917_file4386_yearofbirth_1979_sex_XX.23andme.txt.parquet.
# This file took 28.48 seconds.
#
# Opened 270/404: user595_file277_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 50.28 seconds.
#
# Opened 271/404: user5996_file4506_yearofbirth_1977_sex_XX.23andme.txt.parquet.
# This file took 28.33 seconds.
#
# Opened 272/404: user6013_file4516_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 28.30 seconds.
#
# Opened 273/404: user6020_file4519_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 27.96 seconds.
#
# Opened 274/404: user602_file279_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 48.83 seconds.
#
# Opened 275/404: user6078_file4589_yearofbirth_1980_sex_XY.23andme.txt.parquet.
# This file took 28.15 seconds.
#
# Opened 276/404: user607_file281_yearofbirth_1976_sex_XY.23andme.txt.parquet.
# This file took 48.80 seconds.
#
# Opened 277/404: user60_file27_yearofbirth_1982_sex_XY.23andme.txt.parquet.
# This file took 50.65 seconds.
#
# Opened 278/404: user6110_file4619_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 27.68 seconds.
#
# Opened 279/404: user6120_file4640_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 48.22 seconds.
#
# Opened 280/404: user613_file285_yearofbirth_unknown_sex_XY.23andme.txt.parquet.
# This file took 50.29 seconds.
#
# Opened 281/404: user6169_file4677_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 28.13 seconds.
#
# Opened 282/404: user6191_file5930_yearofbirth_1971_sex_XX.23andme.txt.parquet.
# This file took 36.21 seconds.
#
# Opened 283/404: user6206_file4711_yearofbirth_1972_sex_unknown.23andme.txt.parquet.
# This file took 28.27 seconds.
#
# Opened 284/404: user6206_file4712_yearofbirth_1972_sex_unknown.23andme.txt.parquet.
# This file took 27.84 seconds.
#
# Opened 285/404: user6238_file4736_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 28.10 seconds.
#
# Opened 286/404: user6249_file4745_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 28.17 seconds.
#
# Opened 287/404: user6263_file4912_yearofbirth_1954_sex_XY.23andme.txt.parquet.
# This file took 29.90 seconds.
#
# Opened 288/404: user6284_file4778_yearofbirth_unknown_sex_XX.23andme.txt.parquet.
# This file took 28.16 seconds.
#
# Opened 289/404: user6367_file4857_yearofbirth_1967_sex_XX.23andme.txt.parquet.
# This file took 28.23 seconds.
#
# Opened 290/404: user637_file293_yearofbirth_1989_sex_XY.23andme.txt.parquet.
# This file took 49.12 seconds.
#
# Opened 291/404: user63_file31_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 51.00 seconds.
#
# Opened 292/404: user645_file296_yearofbirth_1978_sex_XY.23andme.txt.parquet.
# This file took 49.35 seconds.
#
# Opened 293/404: user646_file297_yearofbirth_1955_sex_XY.23andme.txt.parquet.
# This file took 50.05 seconds.
#
# Opened 294/404: user64_file30_yearofbirth_1965_sex_XY.23andme.txt.parquet.
# This file took 29.90 seconds.
#
# Opened 295/404: user651_file300_yearofbirth_1962_sex_XY.23andme.txt.parquet.
# This file took 48.98 seconds.
#
# Opened 296/404: user6545_file4946_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 29.99 seconds.
#
# Opened 297/404: user6545_file4947_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 30.06 seconds.
#
# Opened 298/404: user6589_file4987_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 49.80 seconds.
#
# Opened 299/404: user6598_file5001_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 28.12 seconds.
#
# Opened 300/404: user6699_file5093_yearofbirth_1987_sex_XX.23andme.txt.parquet.
# This file took 29.67 seconds.
#
# Opened 301/404: user6758_file5142_yearofbirth_1977_sex_XX.23andme.txt.parquet.
# This file took 28.37 seconds.
#
# Opened 302/404: user675_file313_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 50.22 seconds.
#
# Opened 303/404: user6815_file5202_yearofbirth_1964_sex_XX.23andme.txt.parquet.
# This file took 25.92 seconds.
#
# Opened 304/404: user684_file319_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 50.28 seconds.
#
# Opened 305/404: user6858_file5234_yearofbirth_1944_sex_XY.23andme.txt.parquet.
# This file took 28.42 seconds.
#
# Opened 306/404: user6859_file5235_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 51.84 seconds.
#
# Opened 307/404: user6859_file5236_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 25.60 seconds.
#
# Opened 308/404: user6869_file5242_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 25.96 seconds.
#
# Opened 309/404: user6971_file5370_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 28.00 seconds.
#
# Opened 310/404: user6981_file5377_yearofbirth_unknown_sex_XY.23andme.txt.parquet.
# This file took 28.42 seconds.
#
# Opened 311/404: user7047_file5450_yearofbirth_1990_sex_XY.23andme.txt.parquet.
# This file took 30.22 seconds.
#
# Opened 312/404: user7053_file5459_yearofbirth_1979_sex_XX.23andme.txt.parquet.
# This file took 30.06 seconds.
#
# Opened 313/404: user7089_file5488_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 28.02 seconds.
#
# Opened 314/404: user7097_file5496_yearofbirth_1983_sex_XY.23andme.txt.parquet.
# This file took 26.02 seconds.
#
# Opened 315/404: user7097_file5499_yearofbirth_1983_sex_XY.23andme.txt.parquet.
# This file took 304.2 seconds.
#
# Opened 316/404: user7163_file5948_yearofbirth_1971_sex_XY.23andme.txt.parquet.
# This file took 29.80 seconds.
#
# Opened 317/404: user7163_file5949_yearofbirth_1971_sex_XY.23andme.txt.parquet.
# This file took 60.28 seconds.
#
# Opened 318/404: user717_file333_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 29.77 seconds.
#
# Opened 319/404: user7195_file5578_yearofbirth_1954_sex_XY.23andme.txt.parquet.
# This file took 29.65 seconds.
#
# Opened 320/404: user7218_file5600_yearofbirth_1990_sex_XY.23andme.txt.parquet.
# This file took 30.23 seconds.
#
# Opened 321/404: user721_file336_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 50.10 seconds.
#
# Opened 322/404: user7266_file5643_yearofbirth_1969_sex_XX.23andme.txt.parquet.
# This file took 30.24 seconds.
#
# Opened 323/404: user726_file338_yearofbirth_1966_sex_XY.23andme.txt.parquet.
# This file took 52.25 seconds.
#
# Opened 324/404: user7280_file5651_yearofbirth_1978_sex_XX.23andme.txt.parquet.
# This file took 30.36 seconds.
#
# Opened 325/404: user7359_file5717_yearofbirth_1981_sex_XX.23andme.txt.parquet.
# This file took 30.13 seconds.
#
# Opened 326/404: user745_file352_yearofbirth_1972_sex_XY.23andme.txt.parquet.
# This file took 50.09 seconds.
#
# Opened 327/404: user749_file355_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 50.95 seconds.
#
# Opened 328/404: user74_file48_yearofbirth_unknown_sex_XY.23andme.txt.parquet.
# This file took 50.12 seconds.
#
# Opened 329/404: user758_file387_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 50.42 seconds.
#
# Opened 330/404: user75_file39_yearofbirth_1982_sex_XY.23andme.txt.parquet.
# This file took 50.82 seconds.
#
# Opened 331/404: user761_file360_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 50.34 seconds.
#
# Opened 332/404: user7657_file6002_yearofbirth_1990_sex_XX.23andme.txt.parquet.
# This file took 30.50 seconds.
#
# Opened 333/404: user7685_file6030_yearofbirth_1965_sex_XX.23andme.txt.parquet.
# This file took 30.79 seconds.
#
# Opened 334/404: user7701_file6045_yearofbirth_1999_sex_XX.23andme.txt.parquet.
# This file took 308.5 seconds.
#
# Opened 335/404: user7759_file6108_yearofbirth_1989_sex_XY.23andme.txt.parquet.
# This file took 28.90 seconds.
#
# Opened 336/404: user7783_file6137_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 30.75 seconds.
#
# Opened 337/404: user779_file369_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 50.91 seconds.
#
# Opened 338/404: user782_file371_yearofbirth_unknown_sex_XX.23andme.txt.parquet.
# This file took 50.36 seconds.
#
# Opened 339/404: user784_file400_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 50.87 seconds.
#
# Opened 340/404: user784_file444_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 50.69 seconds.
#
# Opened 341/404: user7876_file6234_yearofbirth_1960_sex_XX.23andme.txt.parquet.
# This file took 29.83 seconds.
#
# Opened 342/404: user792_file377_yearofbirth_1975_sex_XY.23andme.txt.parquet.
# This file took 50.88 seconds.
#
# Opened 343/404: user806_file388_yearofbirth_1967_sex_XY.23andme.txt.parquet.
# This file took 50.74 seconds.
#
# Opened 344/404: user8076_file6405_yearofbirth_1985_sex_XX.23andme.txt.parquet.
# This file took 31.39 seconds.
#
# Opened 345/404: user8089_file6429_yearofbirth_1983_sex_XX.23andme.txt.parquet.
# This file took 31.06 seconds.
#
# Opened 346/404: user808_file390_yearofbirth_unknown_sex_XY.23andme.txt.parquet.
# This file took 53.31 seconds.
#
# Opened 347/404: user811_file393_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 51.79 seconds.
#
# Opened 348/404: user8120_file8903_yearofbirth_unknown_sex_XY.23andme.txt.parquet.
# This file took 30.56 seconds.
#
# Opened 349/404: user8124_file6458_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 29.62 seconds.
#
# Opened 350/404: user8139_file7598_yearofbirth_1983_sex_XX.23andme.txt.parquet.
# This file took 31.87 seconds.
#
# Opened 351/404: user814_file2442_yearofbirth_1986_sex_XY.23andme.txt.parquet.
# This file took 29.60 seconds.
#
# Opened 352/404: user816_file395_yearofbirth_1983_sex_XY.23andme.txt.parquet.
# This file took 51.84 seconds.
#
# Opened 353/404: user8384_file6717_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 31.48 seconds.
#
# Opened 354/404: user8449_file6813_yearofbirth_1986_sex_XY.23andme.txt.parquet.
# This file took 31.32 seconds.
#
# Opened 355/404: user8476_file6841_yearofbirth_unknown_sex_XX.23andme.txt.parquet.
# This file took 29.84 seconds.
#
# Opened 356/404: user8503_file6865_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 51.98 seconds.
#
# Opened 357/404: user86_file159_yearofbirth_1986_sex_XY.23andme.txt.parquet.
# This file took 52.58 seconds.
#
# Opened 358/404: user8701_file7046_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 30.19 seconds.
#
# Opened 359/404: user8731_file7067_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 30.92 seconds.
#
# Opened 360/404: user8737_file7075_yearofbirth_1967_sex_XY.23andme.txt.parquet.
# This file took 51.16 seconds.
#
# Opened 361/404: user8808_file7151_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 31.52 seconds.
#
# Opened 362/404: user8864_file7207_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 31.59 seconds.
#
# Opened 363/404: user8915_file7249_yearofbirth_1992_sex_XY.23andme.txt.parquet.
# This file took 59.86 seconds.
#
# Opened 364/404: user8934_file7318_yearofbirth_1990_sex_XY.23andme.txt.parquet.
# This file took 31.63 seconds.
#
# Opened 365/404: user8966_file7310_yearofbirth_1991_sex_XY.23andme.txt.parquet.
# This file took 31.63 seconds.
#
# Opened 366/404: user8_file2_yearofbirth_unknown_sex_XX.23andme.txt.parquet.
# This file took 52.28 seconds.
#
# Opened 367/404: user9048_file7397_yearofbirth_1950_sex_XX.23andme.txt.parquet.
# This file took 29.68 seconds.
#
# Opened 368/404: user9072_file7413_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 31.91 seconds.
#
# Opened 369/404: user9076_file7415_yearofbirth_1977_sex_XY.23andme.txt.parquet.
# This file took 32.01 seconds.
#
# Opened 370/404: user9101_file7443_yearofbirth_1970_sex_XX.23andme.txt.parquet.
# This file took 32.00 seconds.
#
# Opened 371/404: user915_file451_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 54.27 seconds.
#
# Opened 372/404: user916_file452_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 54.70 seconds.
#
# Opened 373/404: user9172_file7506_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 30.17 seconds.
#
# Opened 374/404: user9185_file7516_yearofbirth_1965_sex_XX.23andme.txt.parquet.
# This file took 28.69 seconds.
#
# Opened 375/404: user9195_file8602_yearofbirth_1984_sex_XY.23andme.txt.parquet.
# This file took 32.43 seconds.
#
# Opened 376/404: user9195_file8730_yearofbirth_1984_sex_XY.23andme.txt.parquet.
# This file took 31.67 seconds.
#
# Opened 377/404: user9213_file7541_yearofbirth_1997_sex_XY.23andme.txt.parquet.
# This file took 56.59 seconds.
#
# Opened 378/404: user922_file460_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 52.33 seconds.
#
# Opened 379/404: user922_file5861_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 52.12 seconds.
#
# Opened 380/404: user9232_file7556_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 52.38 seconds.
#
# Opened 381/404: user9246_file7572_yearofbirth_1986_sex_XY.23andme.txt.parquet.
# This file took 32.16 seconds.
#
# Opened 382/404: user9248_file7575_yearofbirth_1965_sex_XX.23andme.txt.parquet.
# This file took 32.33 seconds.
#
# Opened 383/404: user924_file462_yearofbirth_1985_sex_XY.23andme.txt.parquet.
# This file took 51.89 seconds.
#
# Opened 384/404: user9276_file7595_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 32.14 seconds.
#
# Opened 385/404: user9304_file7624_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 32.05 seconds.
#
# Opened 386/404: user943_file470_yearofbirth_1979_sex_XY.23andme.txt.parquet.
# This file took 52.00 seconds.
#
# Opened 387/404: user9486_file7780_yearofbirth_1992_sex_XY.23andme.txt.parquet.
# This file took 71.80 seconds.
#
# Opened 388/404: user949_file3858_yearofbirth_1972_sex_XY.23andme.txt.parquet.
# This file took 52.80 seconds.
#
# Opened 389/404: user954_file478_yearofbirth_1983_sex_XY.23andme.txt.parquet.
# This file took 52.71 seconds.
#
# Opened 390/404: user9659_file7930_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 32.11 seconds.
#
# Opened 391/404: user966_file479_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 52.34 seconds.
#
# Opened 392/404: user966_file754_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 52.07 seconds.
#
# Opened 393/404: user966_file755_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 52.52 seconds.
#
# Opened 394/404: user9720_file7985_yearofbirth_1992_sex_XY.23andme.txt.parquet.
# This file took 32.16 seconds.
#
# Opened 395/404: user972_file483_yearofbirth_1979_sex_XY.23andme.txt.parquet.
# This file took 52.33 seconds.
#
# Opened 396/404: user972_file7927_yearofbirth_1979_sex_XY.23andme.txt.parquet.
# This file took 76.70 seconds.
#
# Opened 397/404: user9762_file8017_yearofbirth_1969_sex_XY.23andme.txt.parquet.
# This file took 30.24 seconds.
#
# Opened 398/404: user9812_file8071_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 52.28 seconds.
#
# Opened 399/404: user9822_file8081_yearofbirth_1997_sex_XY.23andme.txt.parquet.
# This file took 30.28 seconds.
#
# Opened 400/404: user9869_file8128_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 32.11 seconds.
#
# Opened 401/404: user990_file492_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 53.22 seconds.
#
# Opened 402/404: user9928_file8189_yearofbirth_unknown_sex_unknown.23andme.txt.parquet.
# This file took 53.36 seconds.
#
# Opened 403/404: user99_file49_yearofbirth_1986_sex_XY.23andme.txt.parquet.
# This file took 54.96 seconds.
#
# 0      [AG, TT, AG, GG, GG, GG, AG, GG, CT, CC, AA, C...
# 1      [GG, CT, AG, AG, AG, TT, GG, GG, CC, CC, GG, C...
# 2      [AA, TT, AA, AG, AG, GG, GG, AG, CC, AC, AG, C...
# 3      [AG, CT, AA, GG, GG, GT, GG, AG, CT, CC, GG, C...
# 4      [AA, TT, AA, AG, AG, GT, GG, GG, CC, CC, AA, C...
#                              ...
# 399    [GG, TT, AG, AG, AA, GG, AG, GG, CC, CC, AG, C...
# 400    [AG, CT, AA, AA, AG, TT, AA, GG, CT, CC, AG, C...
# 401    [AG, TT, AG, GG, GG, GG, GG, AG, CC, CC, AG, C...
# 402    [GG, CT, AA, AG, GG, TT, AG, AG, TT, AC, AG, C...
# 403    [GG, TT, AA, GG, AG, GT, GG, AG, CC, CC, GG, C...
# Length: 404, dtype: object
# Finished construction.
# Storing done.

# %%
## THIS IS THE FINAL DATAFRAME 
finished_nicotine_df = pd.read_csv("Nicotine_Dependence_DF.csv")
finished_nicotine_df
# Out:
#                                                 userID rs2455144 rs693734  \
# 0    user10020_file8283_yearofbirth_unknown_sex_unk...        AG       TT
# 1    user1020_file507_yearofbirth_unknown_sex_unkno...        GG       CT
# 2    user1024_file510_yearofbirth_1971_sex_XX.23and...        AA       TT
# 3    user1028_file514_yearofbirth_unknown_sex_unkno...        AG       CT
# 4    user1029_file515_yearofbirth_unknown_sex_unkno...        AA       TT
# ..                                                 ...       ...      ...
# 399  user9822_file8081_yearofbirth_1997_sex_XY.23an...        GG       TT
# 400  user9869_file8128_yearofbirth_unknown_sex_unkn...        AG       CT
# 401  user990_file492_yearofbirth_unknown_sex_unknow...        AG       TT
# 402  user9928_file8189_yearofbirth_unknown_sex_unkn...        GG       CT
# 403  user99_file49_yearofbirth_1986_sex_XY.23andme....        GG       TT
#
#     rs351615 rs12083131 rs12035499 rs10799145 rs7534404 rs630153 rs770718  \
# 0         AG         GG         GG         GG        AG       GG       CT
# 1         AG         AG         AG         TT        GG       GG       CC
# 2         AA         AG         AG         GG        GG       AG       CC
# 3         AA         GG         GG         GT        GG       AG       CT
# 4         AA         AG         AG         GT        GG       GG       CC
# ..       ...        ...        ...        ...       ...      ...      ...
# 399       AG         AG         AA         GG        AG       GG       CC
# 400       AA         AA         AG         TT        AA       GG       CT
# 401       AG         GG         GG         GG        GG       AG       CC
# 402       AA         AG         GG         TT        AG       AG       TT
# 403       AA         GG         AG         GT        GG       AG       CC
#
#      ... rs133662 rs4823776 rs132231 rs130191 rs6009503 rs134461 rs137878  \
# 0    ...       GT        GG       GG       CT        AG       CT       AG
# 1    ...       GT        GG       AG       CT        GG       CT       AG
# 2    ...       GG        GG       AG       CT        AG       TT       GG
# 3    ...       GT        AG       GG       TT        AG       TT       GG
# 4    ...       GT        AG       AG       CC        AA       TT       GG
# ..   ...      ...       ...      ...      ...       ...      ...      ...
# 399  ...       GT        GG       GG       TT        AG       CC       GG
# 400  ...       GT        GG       AG       CC        AG       CC       GG
# 401  ...       TT        AG       AG       CC        GG       CT       GG
# 402  ...       GT        GG       AG       CT        AG       TT       AG
# 403  ...       GT        GG       GG       CT        AG       CT       AG
#
#     rs8142229 rs131749 rs9616812
# 0          CC       CC        CC
# 1          CT       CT        CT
# 2          CC       CC        TT
# 3          CT       CT        CC
# 4          CT       CC        CT
# ..        ...      ...       ...
# 399        CC       CC        CC
# 400        TT       CT        TT
# 401        CT       CT        CC
# 402        CC       CC        CT
# 403        CT       CC        CC
#
# [404 rows x 5627 columns]
